# %%
# Enable Debugging

# %load_ext autoreload
# %autoreload 2

# %%
# !pip install deprecated
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting deprecated
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.17.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: wrapt, deprecated
# Successfully installed deprecated-1.2.18 wrapt-1.17.2

# %%
import copy
import sys
import os

sys.path.append(os.path.abspath("../../"))
from campaign_diagram import *

# %%
# Create the plot with a list of kernel instances

cascade1 = Cascade.fromYAML("./data/example-cascade.yaml")

cascade1.pretty_print()
campaign_diagram1 = CampaignDiagram(cascade1)
campaign_diagram1.draw()
# Out:
# Cascade: Example Cascade
# Kernel(name=Kernel 1, start=0.00, duration=10.00, compute_util=0.70, bw_util=0.50
# Kernel(name=Kernel 2, start=10.00, duration=15.00, compute_util=0.60, bw_util=0.70
# Kernel(name=Kernel 3, start=25.00, duration=12.00, compute_util=0.80, bw_util=0.60
# Cascade duration: 37.00
# Cascade average compute utilization: 0.69
# Cascade average bw utilization: 0.61
